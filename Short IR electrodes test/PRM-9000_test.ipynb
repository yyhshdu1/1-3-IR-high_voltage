# %%
from PRM9000 import PRM9000
import time

with PRM9000(time_offset=time.time(), resource_name="ASRL5::INSTR") as prm:
    print(prm.verification_string)
    for _ in range(10):
        print(prm.ReadValue())
# Out:
# no data
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line: 04/14/25,15:01:00,000038,CPM
# [1.0755226612091064, 0.10856600000000001]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [9.844413757324219, -1]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [19.90209126472473, -1]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [29.970083713531494, -1]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [40.02015137672424, -1]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [50.11995267868042, -1]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line: 04/14/25,15:02:00,000028,CPM
# [60.23574709892273, 0.07999600000000001]
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# [PRM-9000] Raw line:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 print(prm.verification_string)
#       6 for _ in range(10):
# ----> 7     print(prm.ReadValue())
#
# File c:\Users\CeNTREX\Documents\GitHub\1-3-IR-high_voltage\Short IR electrodes test\PRM9000.py:47, in PRM9000.ReadValue(self)
#      46 def ReadValue(self):
# ---> 47     return [time.time() - self.time_offset, self.ReadDoseRate()]
#
# File c:\Users\CeNTREX\Documents\GitHub\1-3-IR-high_voltage\Short IR electrodes test\PRM9000.py:51, in PRM9000.ReadDoseRate(self)
#      49 def ReadDoseRate(self):
#      50     for _ in range(10):
# ---> 51         line = self._read_line()
#      52         print(f"[PRM-9000] Raw line: {line}")
#      53         parts = line.split(",")
#
# File c:\Users\CeNTREX\Documents\GitHub\1-3-IR-high_voltage\Short IR electrodes test\PRM9000.py:70, in PRM9000._read_line(self, method)
#      68 if method == "read":
#      69     try:
# ---> 70         return self.instr.read().strip()
#      71     except pyvisa.errors.VisaIOError:
#      72         return ""
#
# File c:\Users\CeNTREX\anaconda3\envs\small_IR\Lib\site-packages\pyvisa\resources\messagebased.py:519, in MessageBasedResource.read(self, termination, encoding)
#     517 if termination is None:
#     518     termination = self._read_termination
# --> 519     message = self._read_raw().decode(enco)
#     520 else:
#     521     with self.read_termination_context(termination):
#
# File c:\Users\CeNTREX\anaconda3\envs\small_IR\Lib\site-packages\pyvisa\resources\messagebased.py:473, in MessageBasedResource._read_raw(self, size, monitoring_interface)
#     466 while status == loop_status:
#     467     logger.debug(
#     468         "%s - reading %d bytes (last status %r)",
#     469         self._resource_name,
#     470         size,
#     471         status,
#     472     )
# --> 473     chunk, status = self.visalib.read(self.session, size)
#     474     if monitoring_interface:
#     475         monitoring_interface.update(len(chunk))
#
# File c:\Users\CeNTREX\anaconda3\envs\small_IR\Lib\site-packages\pyvisa\ctwrapper\functions.py:2339, in read(library, session, count)
#    2337 buffer = create_string_buffer(count)
#    2338 return_count = ViUInt32()
# -> 2339 ret = library.viRead(session, buffer, count, byref(return_count))
#    2340 return buffer.raw[: return_count.value], ret
#
# File c:\Users\CeNTREX\anaconda3\envs\small_IR\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:185, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     182     for method_name in getattr(self.lib, "_functions", []):
#     183         setattr(self, method_name, getattr(self.lib, method_name))
# --> 185 def _return_handler(self, ret_value: int, func: Callable, arguments: tuple) -> Any:
#     186     """Check return values for errors and warnings."""
#     187     logger.debug(
#     188         "%s%s -> %r",
#     189         func.__name__,
#    (...)    192         extra=self._logging_extra,
#     193     )
#
# KeyboardInterrupt:
